# %% [markdown]
# Task-4: Image to Pencil Sketch with Python
# Description Of Task:
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
#
# Refrence link: https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python/

# %% [markdown]
# # Import Libraries

# %%
import cv2
import numpy as np

# %% [markdown]
# # Read the image using Computer Vision

# %%
image = cv2.imread("mypic.jpg")
image
# Out:
# array([[[ 18,   4,  40],
#         [ 15,   1,  37],
#         [ 11,   0,  33],
#         ...,
#         [ 85,  87, 127],
#         [ 86,  88, 128],
#         [ 89,  91, 131]],
#
#        [[ 20,   6,  42],
#         [ 19,   5,  41],
#         [ 16,   2,  38],
#         ...,
#         [ 83,  85, 125],
#         [ 89,  91, 131],
#         [ 94,  96, 136]],
#
#        [[ 15,   0,  33],
#         [ 15,   0,  33],
#         [ 14,   0,  32],
#         ...,
#         [ 87,  90, 128],
#         [ 88,  91, 129],
#         [ 87,  90, 128]],
#
#        ...,
#
#        [[  6,   2,   1],
#         [  6,   2,   1],
#         [  6,   2,   1],
#         ...,
#         [ 55,  45,  28],
#         [ 55,  47,  30],
#         [ 59,  51,  34]],
#
#        [[  5,   2,   0],
#         [  5,   2,   0],
#         [  5,   1,   0],
#         ...,
#         [ 57,  47,  30],
#         [ 50,  42,  25],
#         [ 48,  40,  23]],
#
#        [[  4,   1,   0],
#         [  4,   1,   0],
#         [  4,   0,   0],
# ...

# %% [markdown]
# # Display Image

# %%
cv2.imshow("Chitranshi", image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Read the image in RGB format

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# # create a new image by converting the original image to greyscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 16,  13,  11, ...,  99, 100, 103],
#        [ 18,  17,  14, ...,  97, 103, 108],
#        [ 12,  12,  11, ..., 101, 102, 101],
#        ...,
#        [  2,   2,   2, ...,  41,  43,  47],
#        [  2,   2,   1, ...,  43,  38,  36],
#        [  1,   1,   0, ...,  41,  38,  38]], dtype=uint8)

# %% [markdown]
# # Inverting Image

# %%
plt.imshow(gray_image)

# %% [markdown]
# # Blur the image by using the Gaussian Function

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[ 16,  13,  11, ...,  99, 100, 103],
#        [ 18,  17,  14, ...,  97, 103, 108],
#        [ 12,  12,  11, ..., 101, 102, 101],
#        ...,
#        [  2,   2,   2, ...,  41,  43,  47],
#        [  2,   2,   1, ...,  43,  38,  36],
#        [  1,   1,   0, ...,  41,  38,  38]], dtype=uint8)

# %% [markdown]
# # Invert the blurred image for final image(pencil sketch)

# %%
plt.imshow(gray_image)

# %%
inverted_image = 255 - gray_image 
#inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)

# %% [markdown]
# # Blur the image by using the Gaussian Function

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.imshow(blurred)

# %% [markdown]
# # Invert the blurred image for final image(pencil sketch)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch)

# %% [markdown]
# # Final Sketch

# %%
cv2.imshow("Chit Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Original image and the pencil sketch

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
